# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %%
titanic_df = pd.read_csv("titanic.csv")
titanic_df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic_df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
titanic_df["embarked_new"]=np.where(titanic_df["Embarked"] == "C", "Cherbourg",
                                    np.where(titanic_df["Embarked"] == "Q", "Queensland",
                                   "Southampton"))

# %%
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked embarked_new
# 0      0         A/5 21171   7.2500   NaN        S  Southampton
# 1      0          PC 17599  71.2833   C85        C    Cherbourg
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Southampton
# ...

# %%
titanic_df["mr_mrs"] = np.where(titanic_df["Name"].str.contains("Mrs."), "Mrs", "Mr")

# %%
plt.plot(titanic_df["Age"], titanic_df["Fair"], #missing something)
# Out:
#   Cell In[32], line 1
#     plt.plot(titanic_df["Age"], titanic_df["Fair"], #missing something)
#                                                                        ^
# SyntaxError: incomplete input

# %%
titanic_df.plot(kind="bar")
# Out:
# <Axes: >

# %%
colors = 
agg_gender = titanic_df.groupby("Sex").count()
agg_gender.plot(kind ="pies", y = "Passenger", color = colors)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 2
#       1 agg_gender = titanic_df.groupby("Sex").count()
# ----> 2 agg_gender.plot(kind ="pies", y = "Passenger", color = colors)
#
# NameError: name 'colors' is not defined
